# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
# Build query URL
query_url = f"{url}{weather_api_key}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bbf8730e341cdc5aa04ea1d7403f4cd9&q=

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        weather_response = requests.get(query_url + city).json()
        city_name.append(weather_response['name'])
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        max_temp.append(weather_response['main']['temp_max'])
        humidity.append(weather_response['main']['humidity'])
        cloudiness.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        print(f"Processing Record for {city}")
    except KeyError:
        print("City not valid")
print("All cities processed")
# Out:
# Processing Record for nanakuli
# Processing Record for kaitangata
# Processing Record for kutum
# Processing Record for albany
# Processing Record for port hardy
# Processing Record for rikitea
# Processing Record for upernavik
# Processing Record for axim
# Processing Record for busselton
# Processing Record for lafia
# Processing Record for hithadhoo
# Processing Record for east london
# City not valid
# Processing Record for punta arenas
# Processing Record for hualmay
# Processing Record for bredasdorp
# Processing Record for port elizabeth
# Processing Record for hermanus
# Processing Record for vao
# Processing Record for ganta
# Processing Record for virginia beach
# Processing Record for mataura
# Processing Record for chuy
# Processing Record for saint-philippe
# Processing Record for bandar-e lengeh
# Processing Record for lorengau
# Processing Record for vaini
# Processing Record for vostok
# Processing Record for lazurne
# Processing Record for hilo
# Processing Record for poopo
# City not valid
# Processing Record for half moon bay
# Processing Record for norman wells
# Processing Record for ushuaia
# City not valid
# Processing Record for vicuna
# Processing Record for pozzallo
# City not valid
# Processing Record for sola
# Processing Record for alta floresta
# Processing Record for iquitos
# Processing Record for manta
# Processing Record for teguldet
# Processing Record for bambous virieux
# Processing Record for avarua
# Processing Record for dhoraji
# Processing Record for balkanabat
# Processing Record for carnarvon
# Processing Record for kaka
# Processing Record for severo-kurilsk
# Processing Record for atuona
# Processing Record for fortuna
# Processing Record for bali
# Processing Record for bluff
# Processing Record for haines junction
# Processing Record for taltal
# Processing Record for grindavik
# City not valid
# Processing Record for westport
# Processing Record for beyneu
# Processing Record for cape town
# Processing Record for new norfolk
# Processing Record for paracatu
# City not valid
# Processing Record for portland
# Processing Record for lebu
# Processing Record for nikolskoye
# Processing Record for krasnogorskiy
# Processing Record for qaanaaq
# Processing Record for georgetown
# Processing Record for baykit
# Processing Record for manado
# Processing Record for talnakh
# Processing Record for coahuayana
# Processing Record for cheltenham
# Processing Record for san cristobal
# Processing Record for buta
# City not valid
# Processing Record for kedrovyy
# Processing Record for karratha
# Processing Record for jamestown
# Processing Record for valdivia
# Processing Record for chernyshevskiy
# Processing Record for luganville
# Processing Record for kruisfontein
# Processing Record for mahebourg
# Processing Record for sioux lookout
# Processing Record for codrington
# Processing Record for ulaangom
# Processing Record for yulara
# Processing Record for saint-joseph
# Processing Record for cayenne
# City not valid
# Processing Record for hilton head island
# Processing Record for san esteban
# Processing Record for beringovskiy
# Processing Record for tuktoyaktuk
# Processing Record for yakima
# Processing Record for khandbari
# Processing Record for arraial do cabo
# City not valid
# Processing Record for luderitz
# Processing Record for faanui
# Processing Record for kapaa
# Processing Record for gladstone
# Processing Record for bandarbeyla
# Processing Record for kahului
# Processing Record for bowen
# Processing Record for kaeo
# Processing Record for husavik
# Processing Record for port hedland
# Processing Record for olinda
# Processing Record for cockburn town
# Processing Record for sisimiut
# Processing Record for povenets
# City not valid
# City not valid
# Processing Record for puerto ayora
# Processing Record for tucume
# Processing Record for juba
# Processing Record for botwood
# Processing Record for kalmunai
# Processing Record for warrnambool
# Processing Record for byron bay
# Processing Record for chokurdakh
# Processing Record for hasaki
# Processing Record for bengkulu
# Processing Record for agadir
# Processing Record for rundu
# City not valid
# Processing Record for gazanjyk
# City not valid
# Processing Record for castro
# Processing Record for pisco
# Processing Record for zelenoborsk
# Processing Record for pedasi
# Processing Record for victoria
# Processing Record for manoel urbano
# City not valid
# Processing Record for nuuk
# Processing Record for ponta do sol
# Processing Record for bethel
# Processing Record for lichtenburg
# Processing Record for aklavik
# Processing Record for souillac
# Processing Record for tacoronte
# Processing Record for fare
# Processing Record for alofi
# Processing Record for tecoanapa
# Processing Record for vestmanna
# Processing Record for santa rosa
# Processing Record for campoverde
# Processing Record for ribeira grande
# Processing Record for kuytun
# Processing Record for makakilo city
# Processing Record for lasa
# Processing Record for tagusao
# Processing Record for khatanga
# Processing Record for baherden
# Processing Record for kodiak
# Processing Record for san patricio
# Processing Record for rocha
# City not valid
# Processing Record for provideniya
# Processing Record for lamu
# Processing Record for salalah
# Processing Record for port alfred
# Processing Record for thompson
# Processing Record for temiscaming
# Processing Record for yellowknife
# Processing Record for road town
# City not valid
# Processing Record for batagay
# Processing Record for catuday
# Processing Record for wanaka
# Processing Record for airai
# Processing Record for chifeng
# Processing Record for fairbanks
# Processing Record for mandalgovi
# Processing Record for banda aceh
# Processing Record for butaritari
# Processing Record for santa isabel
# Processing Record for fort saint james
# Processing Record for san isidro
# Processing Record for ixtapa
# Processing Record for abu dhabi
# Processing Record for tasiilaq
# Processing Record for payson
# Processing Record for nantucket
# Processing Record for vestmannaeyjar
# Processing Record for hobart
# Processing Record for north bend
# Processing Record for bud
# Processing Record for comodoro rivadavia
# Processing Record for haicheng
# Processing Record for tiksi
# Processing Record for saint george
# Processing Record for cairns
# Processing Record for hatillo
# Processing Record for muros
# Processing Record for saskylakh
# Processing Record for sarnia
# Processing Record for meadow lake
# Processing Record for sao joao da barra
# Processing Record for barrow
# Processing Record for ilulissat
# Processing Record for bindura
# Processing Record for batemans bay
# Processing Record for mayor pablo lagerenza
# Processing Record for turukhansk
# Processing Record for vardo
# Processing Record for ornskoldsvik
# Processing Record for luwuk
# Processing Record for kenai
# Processing Record for avera
# Processing Record for hastings
# City not valid
# Processing Record for benguela
# Processing Record for huarmey
# Processing Record for abnub
# Processing Record for kroonstad
# Processing Record for cherepanovo
# Processing Record for cherskiy
# Processing Record for aksu
# Processing Record for caucaia
# Processing Record for fort frances
# Processing Record for tessalit
# Processing Record for ust-nera
# Processing Record for pinhao
# Processing Record for hofn
# Processing Record for cabo san lucas
# Processing Record for egvekinot
# Processing Record for mar del plata
# Processing Record for ahuimanu
# Processing Record for am timan
# Processing Record for shimoda
# Processing Record for praya
# Processing Record for ternate
# Processing Record for lagoa
# Processing Record for torbay
# Processing Record for tarko-sale
# Processing Record for buarcos
# Processing Record for coos bay
# Processing Record for mondolfo
# Processing Record for sarkand
# Processing Record for charlottesville
# Processing Record for belaya gora
# Processing Record for borba
# Processing Record for alice springs
# Processing Record for kyabe
# Processing Record for ahipara
# Processing Record for red bluff
# Processing Record for kiunga
# Processing Record for ayan
# Processing Record for hwange
# Processing Record for klaksvik
# Processing Record for buzovna
# Processing Record for steamboat springs
# Processing Record for san miguel
# Processing Record for mount gambier
# Processing Record for shubarkuduk
# Processing Record for dukat
# Processing Record for tuatapere
# City not valid
# Processing Record for broome
# Processing Record for auki
# Processing Record for henties bay
# Processing Record for salinopolis
# Processing Record for lompoc
# Processing Record for chapais
# Processing Record for derbent
# Processing Record for bukama
# Processing Record for katsuura
# Processing Record for hamilton
# Processing Record for ndele
# Processing Record for kavieng
# Processing Record for grand gaube
# City not valid
# Processing Record for igrim
# Processing Record for longyearbyen
# Processing Record for florianopolis
# Processing Record for whitehorse
# Processing Record for nanortalik
# Processing Record for goundam
# Processing Record for pevek
# Processing Record for vilhena
# Processing Record for buchanan
# Processing Record for koslan
# Processing Record for marzuq
# Processing Record for goderich
# Processing Record for dubti
# City not valid
# Processing Record for sitka
# Processing Record for tombouctou
# Processing Record for sobolevo
# Processing Record for umm lajj
# Processing Record for murakami
# City not valid
# Processing Record for quatre cocos
# Processing Record for kalabo
# Processing Record for bam
# Processing Record for mascota
# Processing Record for te anau
# Processing Record for zandvoort
# Processing Record for mungaoli
# Processing Record for taksimo
# Processing Record for coquimbo
# Processing Record for san policarpo
# Processing Record for mgandu
# Processing Record for clyde river
# Processing Record for dinguiraye
# Processing Record for bilma
# Processing Record for bairnsdale
# Processing Record for defiance
# Processing Record for ancud
# Processing Record for mehamn
# Processing Record for klamath falls
# Processing Record for curup
# Processing Record for silver city
# Processing Record for geraldton
# Processing Record for raudeberg
# Processing Record for iranshahr
# Processing Record for college
# Processing Record for abbeville
# Processing Record for turmalina
# Processing Record for piracuruca
# Processing Record for san quintin
# Processing Record for marystown
# Processing Record for metro
# Processing Record for maroua
# Processing Record for el alto
# Processing Record for arlit
# Processing Record for dikson
# Processing Record for mayo
# Processing Record for urmary
# Processing Record for lvov
# Processing Record for serenje
# Processing Record for meulaboh
# City not valid
# City not valid
# Processing Record for barguzin
# City not valid
# Processing Record for muscle shoals
# Processing Record for tura
# Processing Record for kichera
# Processing Record for laguna
# Processing Record for lethem
# Processing Record for bressanone
# Processing Record for bilsi
# Processing Record for hukuntsi
# Processing Record for tabuk
# City not valid
# Processing Record for tautira
# Processing Record for la ronge
# City not valid
# Processing Record for mpika
# City not valid
# Processing Record for nabire
# Processing Record for villazon
# Processing Record for lubao
# Processing Record for narsaq
# City not valid
# Processing Record for rio gallegos
# Processing Record for pangai
# City not valid
# Processing Record for moree
# Processing Record for skibbereen
# Processing Record for olafsvik
# Processing Record for rosarito
# Processing Record for isangel
# Processing Record for ilhabela
# Processing Record for konstantinovo
# Processing Record for aswan
# Processing Record for kharp
# Processing Record for bantou
# Processing Record for ponta delgada
# City not valid
# Processing Record for saint-pierre
# Processing Record for leningradskiy
# Processing Record for dingle
# Processing Record for lumsden
# Processing Record for boffa
# Processing Record for burnie
# Processing Record for goure
# Processing Record for iqaluit
# Processing Record for sao filipe
# City not valid
# Processing Record for lagunillas
# Processing Record for grand-santi
# Processing Record for berlevag
# Processing Record for plataresti
# Processing Record for jacobabad
# Processing Record for oranjemund
# Processing Record for caconda
# Processing Record for sangar
# Processing Record for ingham
# Processing Record for kalga
# Processing Record for fort abbas
# Processing Record for kavaratti
# Processing Record for cidreira
# Processing Record for maracana
# Processing Record for marabba
# Processing Record for makat
# Processing Record for guantanamo
# Processing Record for periyapatti
# Processing Record for altamira
# City not valid
# City not valid
# Processing Record for esperance
# Processing Record for trinidad
# Processing Record for fukue
# Processing Record for lisakovsk
# Processing Record for zhangjiakou
# City not valid
# Processing Record for bom jardim
# Processing Record for tual
# Processing Record for altay
# Processing Record for wanning
# Processing Record for kishi
# Processing Record for yakeshi
# Processing Record for libertador general san martin
# Processing Record for richards bay
# Processing Record for saint-augustin
# Processing Record for kalur kot
# Processing Record for ostrovnoy
# Processing Record for kabanjahe
# Processing Record for maniitsoq
# Processing Record for rio bueno
# Processing Record for anchorage
# Processing Record for gazli
# Processing Record for leninskoye
# Processing Record for caraballeda
# Processing Record for las cruces
# Processing Record for isla mujeres
# Processing Record for barra do garcas
# Processing Record for dolores
# City not valid
# Processing Record for tevaitoa
# Processing Record for sretensk
# Processing Record for shenjiamen
# Processing Record for kasempa
# Processing Record for amnat charoen
# Processing Record for atar
# Processing Record for flinders
# Processing Record for mangrul pir
# Processing Record for suntar
# Processing Record for songea
# Processing Record for sur
# Processing Record for akodia
# Processing Record for wembley
# Processing Record for vila
# Processing Record for copiapo
# Processing Record for tinskoy
# Processing Record for asau
# City not valid
# City not valid
# Processing Record for acapulco
# Processing Record for martapura
# Processing Record for voh
# Processing Record for doaba
# Processing Record for filadelfia
# Processing Record for phonhong
# Processing Record for tianmen
# Processing Record for kimbe
# Processing Record for gizo
# Processing Record for siderno
# Processing Record for palmer
# Processing Record for kukmor
# Processing Record for dwarka
# Processing Record for oyek
# Processing Record for snezhnogorsk
# Processing Record for tshikapa
# Processing Record for payakumbuh
# City not valid
# Processing Record for waingapu
# Processing Record for xiongzhou
# Processing Record for hobyo
# Processing Record for chiredzi
# Processing Record for arak
# Processing Record for kericho
# Processing Record for neiafu
# Processing Record for dzyhivka
# Processing Record for laizhou
# Processing Record for calama
# City not valid
# Processing Record for cururupu
# Processing Record for gornyy
# Processing Record for tabou
# Processing Record for freeport
# Processing Record for mwingi
# Processing Record for bogashevo
# Processing Record for jardim
# Processing Record for black diamond
# Processing Record for sorong
# Processing Record for bereda
# Processing Record for mogok
# Processing Record for kathmandu
# Processing Record for lukovetskiy
# Processing Record for guerrero negro
# Processing Record for port blair
# Processing Record for voznesenskoye
# Processing Record for warri
# Processing Record for palaikastron
# Processing Record for trairi
# Processing Record for halifax
# Processing Record for matara
# Processing Record for kilvelur
# Processing Record for cap malheureux
# Processing Record for lumby
# Processing Record for izumrud
# Processing Record for bela
# Processing Record for baisha
# Processing Record for letovice
# Processing Record for constitucion
# Processing Record for kisangani
# Processing Record for nouakchott
# Processing Record for almaznyy
# Processing Record for sirnach
# City not valid
# Processing Record for hervey bay
# Processing Record for coihaique
# Processing Record for shingu
# Processing Record for lucea
# Processing Record for morant bay
# Processing Record for tateyama
# Processing Record for tambacounda
# Processing Record for vila velha
# Processing Record for kattivakkam
# Processing Record for shubarshi
# Processing Record for khani
# Processing Record for angoram
# Processing Record for brigantine
# Processing Record for hede
# Processing Record for palauig
# Processing Record for kalemie
# Processing Record for karlskrona
# Processing Record for cerrito
# Processing Record for kargasok
# Processing Record for paamiut
# Processing Record for santa isabel do rio negro
# Processing Record for macklin
# Processing Record for wajir
# Processing Record for northam
# Processing Record for nyazepetrovsk
# Processing Record for brownsville
# Processing Record for kyra
# Processing Record for bonthe
# Processing Record for tak bai
# Processing Record for saldanha
# Processing Record for cervia
# City not valid
# Processing Record for brekstad
# Processing Record for lufilufi
# Processing Record for hirara
# Processing Record for aksarka
# Processing Record for belyy yar
# Processing Record for nybro
# Processing Record for ati
# Processing Record for marsa matruh
# City not valid
# Processing Record for kumluca
# Processing Record for doembang nangbuat
# Processing Record for tutoia
# Processing Record for kajaani
# Processing Record for zhigansk
# Processing Record for camana
# Processing Record for the valley
# Processing Record for korcula
# Processing Record for touros
# Processing Record for sorland
# Processing Record for deputatskiy
# Processing Record for tilichiki
# Processing Record for shache
# Processing Record for taguatinga
# Processing Record for san miguel de cauri
# Processing Record for bukachacha
# Processing Record for hambantota
# Processing Record for impfondo
# Processing Record for fuerte olimpo
# City not valid
# Processing Record for maracaju
# Processing Record for binzhou
# Processing Record for carahue
# Processing Record for krasnyy chikoy
# Processing Record for pacific grove
# Processing Record for baracoa
# Processing Record for carutapera
# All cities processed

# %%
weather_dict = {
    "City":city_name,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":date
}

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nouadhibou  20.9310  -17.0347     78.78        69           0
# 1  Guerrero Negro  27.9769 -114.0611     69.98        77          91
# 2            Hilo  19.7297 -155.0900     75.79        97          90
# 3       Siniscola  40.5719    9.6922     94.55        39          98
# 4  Saint-Philippe -21.3585   55.7679     69.39        78          37
#
#    Wind Speed Country        Date
# 0       13.80      MR  1627224596
# 1        8.68      MX  1627224597
# 2        5.75      US  1627224400
# 3       12.68      IT  1627224597
# 4       12.10      RE  1627224597

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#There are no cities with humidity over 100 percent

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis = weather_df['Lat'] 
temp = weather_df['Max Temp']

fig1, ax1  = plt.subplots(figsize=(15, 10))
markersize=10
plt.title('City Latitude vs Temperature',fontsize =20)
plt.scatter(x_axis, temp , marker="o",color="blue")
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Temperature',fontsize =15)
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_axis = weather_df['Lat'] 
hum = weather_df['Humidity']

fig1, ax1  = plt.subplots(figsize=(15, 10))
markersize=10
plt.title('Latitude vs Humidity',fontsize =20)
plt.scatter(x_axis, hum , marker="o",color="blue")
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Humidity',fontsize =15)
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_axis = weather_df['Lat'] 
cloud = weather_df['Cloudiness']

fig1, ax1  = plt.subplots(figsize=(15, 10))
markersize=10
plt.title('Latitude vs Cloudiness',fontsize =20)
plt.scatter(x_axis, cloud , marker="o",color="blue")
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Cloudiness',fontsize =15)
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_axis = weather_df['Lat'] 
wind = weather_df['Wind Speed']

fig1, ax1  = plt.subplots(figsize=(15, 10))
markersize=10
plt.title('Latitude vs Wind Speed',fontsize =20)
plt.scatter(x_axis, cloud , marker="o",color="blue")
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Wind Speed',fontsize =15)
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
